# %%
#Importing needed libaraies

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
#Sorting the dataset into df variable then printing it

df=pd.read_csv('advertising.csv')
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
#Printing first five rows of the dataframe

df.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
#Printing the last five rows of the dataframe

df.tail()
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
#Printing the shape of the dataframe

df.shape
# Out:
# (200, 5)

# %%
#Printing all the datatypes of the dataset

df.dtypes
# Out:
# Unnamed: 0      int64
# TV            float64
# radio         float64
# newspaper     float64
# sales         float64
# dtype: object

# %%
#Printing all the columns of the dataset

df.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %%
#Printing skewness present in each column

df.skew()
# Out:
# Unnamed: 0    0.000000
# TV           -0.069853
# radio         0.094175
# newspaper     0.894720
# sales         0.407571
# dtype: float64

# %%
#Getting the information of the dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   radio       200 non-null    float64
#  3   newspaper   200 non-null    float64
#  4   sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
#Checking is there any null values present into the dataset

df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# radio         0
# newspaper     0
# sales         0
# dtype: int64

# %%
#Plotting with the heatmap to get a better understanding

sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # STATISTICAL SUMMARY

# %%
#Getting the statistical summary of the dataset

df.describe()
# Out:
#        Unnamed: 0          TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# # DATA VISUALIZATION

# %% [markdown]
# # UNIVARIET ANALYSIS

# %%
#Plotting countplot of sales

sns.countplot(data=df,x='sales')
# Out:
# <AxesSubplot:xlabel='sales', ylabel='count'>

# %%
#The graph is normally distributed we can see that via plotting it through distribution plot

sns.distplot(df['sales'])
# Out:
# <AxesSubplot:xlabel='sales', ylabel='Density'>

# %%
#There are no outliers present in the Survived column

sns.boxplot(df['sales'])
# Out:
# <AxesSubplot:xlabel='sales'>

# %%
#Plotting violinplot it shows that it is more concentrated b/w 5 to 23 approximately

sns.violinplot(df['sales'])
# Out:
# <AxesSubplot:xlabel='sales'>

# %%
#Plotting histogram for sales

sns.histplot(df['sales'],bins=5)
# Out:
# <AxesSubplot:xlabel='sales', ylabel='Count'>

# %% [markdown]
# # BI-VARIET ANALYSIS

# %%
#Printing the catplot showing relation b/w sales & newspaper

sns.catplot(x='sales',y='newspaper',data=df)

# %%
#Plotting stripplot of sales & newspaper

sns.stripplot(x='sales',y='newspaper',data=df)
# Out:
# <AxesSubplot:xlabel='sales', ylabel='newspaper'>

# %%
#Plotting swarmplot of sales & newspaper

sns.swarmplot(x='sales',y='newspaper',data=df)
# Out:
# <AxesSubplot:xlabel='sales', ylabel='newspaper'>

# %%
#Plotting lineplot of sales & newspaper

sns.lineplot(x='sales',y='newspaper',data=df)
# Out:
# <AxesSubplot:xlabel='sales', ylabel='newspaper'>

# %%
#Plotting the relational plot of sales & newspaper

sns.relplot(x='sales',y='newspaper',data=df)

# %%
#Plotting scatter plot

plt.scatter(df['sales'],df['newspaper'])
plt.show()

# %%
#Plotting lmplot of sales & newspaper

sns.lmplot('sales','newspaper',data=df)

# %%
#Plotting joint plot

sns.jointplot(x='sales',y='newspaper',data=df)

# %%
#Plotting kdeplot 

sns.kdeplot(x='sales',y='newspaper',data=df)
# Out:
# <AxesSubplot:xlabel='sales', ylabel='newspaper'>

# %% [markdown]
# # MULTIVAIRET ANALYSIS

# %%
#Plotting all the columns interrelatedly with other & showing all the graphs possible

sns.pairplot(df)

# %%
#Plotting kdeplots of all the columns

df.plot(kind='kde',subplots=True,layout=(2,6),figsize=(15,5))
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>]],
#       dtype=object)

# %%
#Plotting all the boxplots of all the columns

df.plot(kind='box',subplots=True,layout=(2,6),figsize=(15,5))
# Out:
# Unnamed: 0       AxesSubplot(0.125,0.536818;0.110714x0.343182)
# TV            AxesSubplot(0.257857,0.536818;0.110714x0.343182)
# radio         AxesSubplot(0.390714,0.536818;0.110714x0.343182)
# newspaper     AxesSubplot(0.523571,0.536818;0.110714x0.343182)
# sales         AxesSubplot(0.656429,0.536818;0.110714x0.343182)
# dtype: object

# %% [markdown]
# # CO-RELATION

# %%
#Printing the corelations of the columns

dfcor=df.corr()
dfcor
# Out:
#             Unnamed: 0        TV     radio  newspaper     sales
# Unnamed: 0    1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV            0.017715  1.000000  0.054809   0.056648  0.782224
# radio        -0.110680  0.054809  1.000000   0.354104  0.576223
# newspaper    -0.154944  0.056648  0.354104   1.000000  0.228299
# sales        -0.051616  0.782224  0.576223   0.228299  1.000000

# %%
#All the lighter colors are highly corelated

sns.heatmap(dfcor)
# Out:
# <AxesSubplot:>

# %%
#Here we can see all the column names simantaneously 
#Here all the darker shades are highly corelated

sns.heatmap(dfcor,annot=True,cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
#Showing all the columns  positively & negatively corelated

plt.figure(figsize=(22,7))
df.corr()['sales'].sort_values(ascending=False).drop(['sales']).plot(kind='bar')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %% [markdown]
# # DROP COLUMN THAT WE DON'T NEED

# %%
#Droped the Unnamed: 0 column from the dataset as we don't need it  

df=df.drop('Unnamed: 0',axis=1)

# %%
#Printing the dataframe after removing the column Unnamed: 0

df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %% [markdown]
# # DIVIDING INTO TRAINING & TESTING PHASE

# %%
#Dividing the data into training & testing phase

x=df.drop(['newspaper','sales'],axis=1)
y=df['sales']

# %%
#Checking skewness

x.skew()
# Out:
# TV      -0.069853
# radio    0.094175
# dtype: float64

# %%
#Printing the shape of x & y

print(x.shape)
print(y.shape)
# Out:
# (200, 2)
# (200,)

# %% [markdown]
# # MODELS

# %%
#Importing models

from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
#Importing train_test_split for sending the data to the training & testing phase
#Using ofr loop for determining the Max accuracy at which random state

from sklearn.model_selection import train_test_split 
from sklearn.metrics import r2_score
maxAccu=0
maxRS=0
for i in range (1,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
    lr.fit(x_train,y_train)
    predr=lr.predict(x_test)
    acc=r2_score(y_test,predr)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print(maxAccu)
print(maxRS)
# Out:
# 0.9332116756936784
# 13

# %%
#Importing all the models

from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor

# %%
#Creating all the instances of the models

dr=DecisionTreeRegressor()
svr=SVR() 
rf=RandomForestRegressor()

# %%
#Using for loop to print the r2score, accuracy & mean squared errors of all the models

from sklearn.metrics import mean_squared_error,mean_absolute_error

model=[lr,dr,svr,rf]
for m in model:
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=13)
    m.fit(x_train,y_train)
    predl=m.predict(x_test)
    print('r2_score of',m,'is:')
    print(r2_score(y_test,predl))
    print('mean_squared_error:',mean_squared_error(y_test,predl))
    print('mean_absolute_error:',mean_absolute_error(y_test,predl))
    print('root_mean_squared_error',np.sqrt(mean_squared_error(y_test,predl)))
    print('\n')
# Out:
# r2_score of LinearRegression() is:
# 0.9332116756936784
# mean_squared_error: 2.116464670622304
# mean_absolute_error: 1.2175373257978157
# root_mean_squared_error 1.4548074342064328
#
#
# r2_score of DecisionTreeRegressor() is:
# 0.9679069881192217
# mean_squared_error: 1.0169999999999995
# mean_absolute_error: 0.7899999999999999
# root_mean_squared_error 1.0084641788382964
#
#
# r2_score of SVR() is:
# 0.8307354629106862
# mean_squared_error: 5.363847894966018
# mean_absolute_error: 1.6787408791180034
# root_mean_squared_error 2.315998250207892
#
#
# r2_score of RandomForestRegressor() is:
# 0.9780697168351831
# mean_squared_error: 0.6949518499999996
# mean_absolute_error: 0.6461499999999999
# root_mean_squared_error 0.8336377210755279

# %% [markdown]
# # CROSS VALIDATION

# %%
from sklearn.model_selection import cross_val_score

# %%
modelss=[lr,dr,svr,rf]

for i in modelss:
    print(cross_val_score(i,x,y,cv=5).mean())
# Out:
# 0.889282957306453
# 0.958965666093528
# 0.8643453266859801
# 0.977960293786633

# %% [markdown]
# # HYPER PARAMETER TUNNING

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_param={'criterion':['mse','mae']}
gd=GridSearchCV(estimator=rf,param_grid=grid_param,scoring='r2',cv=5)
gd.fit(x,y)
best_parameter=gd.best_params_
print('best_parameter:',best_parameter)
# Out:
# best_parameter: {'criterion': 'mae'}

# %%
gd_pred=gd.best_estimator_.predict(x_test)
gd_pred
# Out:
# array([12.779,  3.98 , 15.394, 12.988, 11.586, 25.083, 20.596, 13.229,
#        24.437, 15.475, 17.029,  7.234,  9.55 , 16.861, 14.373, 16.401,
#         5.625, 11.138, 20.405, 18.253, 11.853,  9.614, 21.166, 12.994,
#        17.005, 19.814, 10.339, 11.896, 23.298,  4.853, 15.725, 19.125,
#        18.519,  8.939, 17.617,  9.855, 11.113, 22.676,  7.851, 11.793,
#        10.448, 19.112, 22.339,  5.438, 12.296, 22.051, 19.271, 11.395,
#         8.982, 22.026, 20.706, 10.556, 11.094, 11.884,  9.564, 14.875,
#        24.267,  7.379,  6.116,  9.893])

# %%
r2_score(y_test,gd_pred)
# Out:
# 0.9978225280636349

# %% [markdown]
# # SAVING THE MODEL

# %%
import joblib

joblib.dump(gd.best_estimator_,'sales_adver.pkl')
# Out:
# ['sales_adver.pkl']

# %%
s_a_model=joblib.load('sales_adver.pkl')

# %% [markdown]
# # CONCLUSION

# %%
import numpy as np
a = np.array(y_test)
predicted = np.array(gd.predict(x_test))
df_new = pd.DataFrame({"Original":a,"Predicted":predicted},index= range(len(a)))
df_new
# Out:
#     Original  Predicted
# 0       12.6     12.779
# 1        3.2      3.980
# 2       15.5     15.394
# 3       12.9     12.988
# 4       11.7     11.586
# 5       25.5     25.083
# 6       20.7     20.596
# 7       13.4     13.229
# 8       24.7     24.437
# 9       15.5     15.475
# 10      16.9     17.029
# 11       7.2      7.234
# 12       9.3      9.550
# 13      17.4     16.861
# 14      14.8     14.373
# 15      16.7     16.401
# 16       5.7      5.625
# 17      11.0     11.138
# 18      20.7     20.405
# 19      18.3     18.253
# 20      11.7     11.853
# 21       9.7      9.614
# 22      21.4     21.166
# 23      13.2     12.994
# 24      17.1     17.005
# 25      19.7     19.814
# 26      10.1     10.339
# 27      11.9     11.896
# 28      23.8     23.298
# 29       5.3      4.853
# 30      16.0     15.725
# 31      19.2     19.125
# 32      19.2     18.519
# 33       8.6      8.939
# 34      18.0     17.617
# 35       9.7      9.855
# 36      11.2     11.113
# ...
